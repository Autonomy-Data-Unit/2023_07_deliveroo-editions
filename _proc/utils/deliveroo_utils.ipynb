# %% [raw]
# ---
# output-file: deliveroo_utils.html
# title: Deliveroo
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(get_restaurant_tags)
# Out:
# ---
#
# [source](https://github.com/ribenamaplesyrup/deliveroo-editions/blob/main/deliveroo_editions/deliveroo_utils.py#L30){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_restaurant_tags
#
# >      get_restaurant_tags (url:str, driver=None)
#
# Returns all list elements from Deliveroo restaurants webpage corresponding to a restaurant
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | url | str |  | URL for Deliveroo restaurants page |
# | driver | NoneType | None |  |

# %%
#| echo: false
#| output: asis
show_doc(get_timestamp)
# Out:
# ---
#
# [source](https://github.com/ribenamaplesyrup/deliveroo-editions/blob/main/deliveroo_editions/deliveroo_utils.py#L48){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_timestamp
#
# >      get_timestamp (url:str)
#
# Returns YYYYMMDD timestamp from url of format: https://web.archive.org/web/YYYYMMDD/
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | url | str | URL for Deliveroo |

# %%
#| echo: false
#| output: asis
show_doc(add_timestamps_to_restaurants)
# Out:
# ---
#
# [source](https://github.com/ribenamaplesyrup/deliveroo-editions/blob/main/deliveroo_editions/deliveroo_utils.py#L61){target="_blank" style="float:right; font-size:smaller"}
#
# ### add_timestamps_to_restaurants
#
# >      add_timestamps_to_restaurants (restaurants, url)

# %%
#| echo: false
#| output: asis
show_doc(get_restaurants)
# Out:
# ---
#
# [source](https://github.com/ribenamaplesyrup/deliveroo-editions/blob/main/deliveroo_editions/deliveroo_utils.py#L81){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_restaurants
#
# >      get_restaurants (url:str, driver=None)
#
# Gets the restaurant `name`, editions `location` and Deliveroo `restaurant_url`
# for each restaurant on url page.
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | url | str |  | URL for Deliveroo restaurants page |
# | driver | NoneType | None | headless:bool=True, |

# %%
metadata = get_restaurants("https://web.archive.org/web/20201019/https://deliveroo.co.uk/restaurants/brighton/brighton-editions?tags=deliveroo+editions")
assert metadata == [{'name': 'Oowee Vegan',
  'location': 'brighton',
  'edition': 'brighton-editions',
  'restaurant_url': 'https://deliveroo.co.uk/menu/brighton/brighton-editions/oowee-vegan-editions-bnc?day=today&geohash=gcpc5qr68ee1&time=ASAP'},
 {'name': 'Shake Shack',
  'location': 'brighton',
  'edition': 'brighton-editions',
  'restaurant_url': 'https://deliveroo.co.uk/menu/brighton/brighton-editions/shake-shack-editions-bnc?day=today&geohash=gcpc5qr68ee1&time=ASAP'},
 {'name': 'Lost Boys Chicken',
  'location': 'brighton',
  'edition': 'hove',
  'restaurant_url': 'https://deliveroo.co.uk/menu/brighton/hove/lost-boys-chicken-editions?day=today&geohash=gcpc5qr68ee1&time=ASAP'},
 {'name': 'The Athenian',
  'location': 'brighton',
  'edition': 'brighton-editions',
  'restaurant_url': 'https://deliveroo.co.uk/menu/brighton/brighton-editions/the-athenian-editions-bnc-new?day=today&geohash=gcpc5qr68ee1&time=ASAP'},
 {'name': 'The Great British Cheesecake Company ',
  'location': 'brighton',
  'edition': 'brighton-editions',
  'restaurant_url': 'https://deliveroo.co.uk/menu/brighton/brighton-editions/the-great-british-cheesecake-company-editions-bnc?day=today&geohash=gcpc5qr68ee1&time=ASAP'},
 {'name': 'The Athenian Plant Based',
  'location': 'brighton',
  'edition': 'brighton-editions',
  'restaurant_url': 'https://deliveroo.co.uk/menu/brighton/brighton-editions/the-athenian-plant-based-editions-bnc-new?day=today&geohash=gcpc5qr68ee1&time=ASAP'},
 {'name': 'The Ice Cream Store',
  'location': 'brighton',
  'edition': 'brighton-editions',
  'restaurant_url': 'https://deliveroo.co.uk/menu/brighton/brighton-editions/the-ice-cream-store-editions-bnc?day=today&geohash=gcpc5qr68ee1&time=ASAP'},
 {'name': 'Pleesecakes - cheesecake',
  'location': 'brighton',
  'edition': 'brighton-editions',
  'restaurant_url': 'https://deliveroo.co.uk/menu/brighton/brighton-editions/pleesecakes-editions-bnc?day=today&geohash=gcpc5qr68ee1&time=ASAP'},
 {'name': 'TRIP CBD Store\t',
  'location': 'brighton',
  'edition': 'brighton-editions',
  'restaurant_url': 'https://deliveroo.co.uk/menu/brighton/brighton-editions/trip-cbd-store-editions-bnc?day=today&geohash=gcpc5qr68ee1&time=ASAP'},
 {'name': 'Halo Top',
  'location': 'brighton',
  'edition': 'brighton-editions',
  'restaurant_url': 'https://deliveroo.co.uk/menu/brighton/brighton-editions/halo-top?day=today&geohash=gcpc5qr68ee1&time=ASAP'},
 {'name': 'VIP Very Italian Pizza',
  'location': 'brighton',
  'edition': 'brighton-editions',
  'restaurant_url': 'https://deliveroo.co.uk/menu/brighton/brighton-editions/vip-italy-limited-hove?day=today&geohash=gcpc5qr68ee1&time=1715'},
 {'name': 'A Burgers Veggie Kitchen  by Taster',
  'location': '',
  'edition': 'brighton-editions',
  'restaurant_url': ''},
 {'name': 'Saucybird',
  'location': '',
  'edition': 'brighton-editions',
  'restaurant_url': ''}]
# Out:
# list index out of range
# Couldn't get metadata for A Burgers Veggie Kitchen  by Taster in https://web.archive.org/web/20201019/https://deliveroo.co.uk/restaurants/brighton/brighton-editions?tags=deliveroo+editions
# list index out of range
# Couldn't get metadata for Saucybird in https://web.archive.org/web/20201019/https://deliveroo.co.uk/restaurants/brighton/brighton-editions?tags=deliveroo+editions

# %%
#| echo: false
#| output: asis
show_doc(search_deliveroo)
# Out:
# ---
#
# [source](https://github.com/ribenamaplesyrup/deliveroo-editions/blob/main/deliveroo_editions/deliveroo_utils.py#L119){target="_blank" style="float:right; font-size:smaller"}
#
# ### search_deliveroo
#
# >      search_deliveroo (address:str, driver=None)
#
# Searches Deliveroo for an address, returning webdriver element once search results page has loaded.
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | address | str |  | UK address containing a UK postcode |
# | driver | NoneType | None | Initialised Selenium webdriver |

# %%
#| echo: false
#| output: asis
show_doc(results_to_editions_url)
# Out:
# ---
#
# [source](https://github.com/ribenamaplesyrup/deliveroo-editions/blob/main/deliveroo_editions/deliveroo_utils.py#L159){target="_blank" style="float:right; font-size:smaller"}
#
# ### results_to_editions_url
#
# >      results_to_editions_url (url:str)
#
# Apply `deliveroo+editions` filter to Deliveroo search results url
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | url | str | Deliveroo search results url |

# %%
#| echo: false
#| output: asis
show_doc(if_editions)
# Out:
# ---
#
# [source](https://github.com/ribenamaplesyrup/deliveroo-editions/blob/main/deliveroo_editions/deliveroo_utils.py#L168){target="_blank" style="float:right; font-size:smaller"}
#
# ### if_editions
#
# >      if_editions (test_url, driver=None)
#
# Check if results page includes editions
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | test_url |  |  | editions url |
# | driver | NoneType | None |  |

# %%
#| echo: false
#| output: asis
show_doc(get_editions)
# Out:
# ---
#
# [source](https://github.com/ribenamaplesyrup/deliveroo-editions/blob/main/deliveroo_editions/deliveroo_utils.py#L191){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_editions
#
# >      get_editions (url:str, driver=None)
#
# Returns a list of editions location
# from all the editions restaurants on url page ie 'bristol-editions'.
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | url | str |  | URL for Deliveroo search results page |
# | driver | NoneType | None | headless:bool=True, |

# %%
test_url = "https://deliveroo.co.uk/restaurants/london/globe-town?fulfillment_method=DELIVERY&geohash=gcpvnuuyrtud"
get_editions(test_url)
# Out:
# ['london/whitechapel-editions',
#  'london/canary-wharf',
#  'london/canning-town-editions',
#  'london/caledonian-road-and-barnsbury',
#  'london/fish-island-area',
#  'london/blackwall']

# %%
test_url = "https://deliveroo.co.uk/restaurants/edinburgh/morningside-road/?fulfillment_method=DELIVERY&geohash=gcvwnvqmt9de"
get_editions(test_url)
# Out:
# ['edinburgh/new-town']

# %%
#| echo: false
#| output: asis
show_doc(get_restaurants_from_editions_location)
# Out:
# ---
#
# [source](https://github.com/ribenamaplesyrup/deliveroo-editions/blob/main/deliveroo_editions/deliveroo_utils.py#L214){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_restaurants_from_editions_location
#
# >      get_restaurants_from_editions_location (editions_list:list)
#
# gets restaurant metadata for all restaurants based at listed editions locations
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | editions_list | list | list of editions locations ie ['london/whitechapel-editions','london/canary-wharf'] |

# %%
#| echo: false
#| output: asis
show_doc(get_editions_locations_near_addresses)
# Out:
# ---
#
# [source](https://github.com/ribenamaplesyrup/deliveroo-editions/blob/main/deliveroo_editions/deliveroo_utils.py#L228){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_editions_locations_near_addresses
#
# >      get_editions_locations_near_addresses (addresses:list, driver=None)
#
# Returns a list of all editions locations found when searching all the restaurants at or near the list of addresses
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | addresses | list |  | list of address strings to search Deliveroo's website for |
# | driver | NoneType | None |  |

# %%
#| echo: false
#| output: asis
show_doc(remove_time_from_url)
# Out:
# ---
#
# [source](https://github.com/ribenamaplesyrup/deliveroo-editions/blob/main/deliveroo_editions/deliveroo_utils.py#L258){target="_blank" style="float:right; font-size:smaller"}
#
# ### remove_time_from_url
#
# >      remove_time_from_url (url)

# %%
#| echo: false
#| output: asis
show_doc(get_address_from_restaurant_url)
# Out:
# ---
#
# [source](https://github.com/ribenamaplesyrup/deliveroo-editions/blob/main/deliveroo_editions/deliveroo_utils.py#L268){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_address_from_restaurant_url
#
# >      get_address_from_restaurant_url (url:str, driver=None)
#
# scrape restaurant address from Deliveroo page
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | url | str |  | Deliveroo URL |
# | driver | NoneType | None |  |

# %%
url = "https://deliveroo.co.uk/menu/Nottingham/nottingham-editions/wawin-vegan-chinese-editions-ntg?geohash=gcrjm0h9b43k"
get_address_from_restaurant_url(url)
# Out:
# 'Unit 1,Redwood Court, Salisbury Street, Nottingham, NG72BQ'
