# %% [raw]
# ---
# description: In this example, we will scrape Deliveroo for additional information
#   on dark kitchen locations to map all sites in the UK.
# output-file: map.html
# title: Map
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
# read the data in

# %%
# visit the restaurant URL

# %%
# extract the address

# %%
# lookup the address and get coords

# %%
# plot coords on Leaflet map
