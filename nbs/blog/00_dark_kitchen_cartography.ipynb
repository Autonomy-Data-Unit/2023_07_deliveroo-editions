# %% [markdown]
# # Dark Kitchen Cartography

# %% [markdown]
# ![](assets/cover.png)

# %% [markdown]
# Dedicated sites for preparing takeaway meals for delivery only, known as "dark kitchens", have become a widely adopted model in the food service industry throughout the past half decade. The separation of a restaurant's delivery business from it's in-house business enables the delivery business to be operated from non-residential central locations where overhead and operating costs are reduced. Researching the successes and failures of this service model could provide useful insights for economic planning, risk management and food distribution, however there is a lack of detailed data on the growth and current state of dark kitchens within the UK.
#
# To the best of our knowledge, a map of the UK's dark kitchen locations does not exist. Therefore we set out to make one for Deliveroo's UK dark kitchen facilities, known as 'Editions', to better understand their growth and current state.
#
# **Disclaimer: all data was gathered before Wednesday 19th July 2023 and may no longer be available.**

# %% [markdown]
# <!-- ![](assets/pkl.png) -->

# %% [markdown]
# ## Locating Deliveroo's Editions

# %% [markdown]
# Deliveroo Editions was launched in May 2017 as a 'concept that puts an end to postcode food envy'. The concept was trialed in Camberwell, Battersea, Dulwich and Canary Wharf before scaling to [30 locations across the UK](https://www.wired.co.uk/article/deliveroo-editions-local-restaurants) within the first year. The Internet Archive's Wayback Machine maintains a capture of the webpage for the original Deliveroo Editions announcement.

# %% [markdown]
# ![](assets/editions_launch.png)

# %% [markdown]
# Deliveroo disloses to users which restaurants are based at Editions facilities within the platform. We can filter restaurant search results for Editions partners by adding `tags=deliveroo+editions` as a query string in our URL when searching for restaurants within a given location. For example to find all the Editions partners delivering to Stepney Green, we can try `https://deliveroo.co.uk/restaurants/london/stepney-green?fulfillment_method=DELIVERY&tags=deliveroo+editions`:

# %% [markdown]
# ![](assets/query.png)

# %% [markdown]
# If we check out Popeyes Louisiana Kitchen which is an Editions partner, we can find the name Deliveroo has given the Editions site from the restaurant's url: `https://deliveroo.co.uk/menu/London/whitechapel-editions/popeyes-editions-wme/?day=today&geohash=gcpvngtckn3c&time=ASAP` which is "Whitechapel Editions" in this case. We can conclude that Popeyes Louisiana Kitchen is also the address for Whitechapel Editions which happens to be 10 Assembly Passage, London, E14UT, a [2-storey B-class office space with a disco ball included built in 1906](https://www.loopnet.co.uk/Listing/10-40-Assembly-Passage-London/8354101/) right next to the busy A11 road into central London.

# %% [markdown]
# ![](assets/assembly.jpeg)

# %% [markdown]
# To find all the other restaurants based at the Whitechapel Editions kitchen, we could search for editions restaurants near the editions name: `https://deliveroo.co.uk/restaurants/london/whitechapel-editions?fulfillment_method=DELIVERY&category=deliveroo+editions`. We can deduce that all the restaurants based 0.0 miles away are those at the editions kitchen and can validate this by checking for `whitechapel-editions` in their urls.

# %% [markdown]
# ![](assets/whitechapel.png)

# %% [markdown]
# We can identify the following restaurants as partners at Whitechapel Editions:
# - Popeyes Louisiana Kitchen
# - Yacob's Kitchen
# - Remedy Kitchen
# - So Noodle - 一汤一粉
# - Hare & Tortoise
# - 🌴 Poke Shack - Whitechapel🌴
# - Zzetta - Soul Fired Pizza
# - TRIP CBD Store
# - Remeo Gelato
# - Ice Cream Store (Editions Whitechapel)
# - Ben & Jerry's Store (Editions Whitechapel)
# - Tao Tao Ju 陶陶居
# - Jude's Ice Cream
# - Motu Indian Kitchen
# - Dishoom

# %% [markdown]
# Using this approach, we can trawl the Internet Archive for historic data beyond Whitechapel.

# %% [markdown]
# ## Historic Data
#
# Deliveroo's website has been archived many times by the Wayback Machine including search results specific to UK locations with Deliveroo Editions filters. Unfortunately only 46 search urls with only several captures at most over a period of 2 years could be retrieved so the data is likely too sparse to help map the growth of Editions in the UK.

# %% [markdown]
# ![](assets/wayback.png)

# %% [markdown]
# Using Selenium, we can iterate through every capture extracting the restaurant names, restaurant urls, editions and timestamps to create a dataset of over 500 partners:

# %%
import pandas as pd 
df = pd.read_csv('data/editions_wayback.csv', usecols=['name','location','timestamps','timestamp_urls','restaurant_url'])
df.head()
# Out:
#                                     name           location  \
# 0                            Oowee Vegan  brighton-editions
# 1                            Shake Shack  brighton-editions
# 2                      Lost Boys Chicken               hove
# 3                           The Athenian  brighton-editions
# 4  The Great British Cheesecake Company   brighton-editions
#
#                                           timestamps  \
# 0                           ['20201019', '20201021']
# 1                           ['20201019', '20201021']
# 2  ['20201019', '20210618', '20210123', '20201021...
# 3  ['20201019', '20210618', '20210123', '20201021...
# 4  ['20201019', '20210618', '20210123', '20210511...
#
#                                       timestamp_urls  \
# 0  ['https://web.archive.org/web/20201019/https:/...
# 1  ['https://web.archive.org/web/20201019/https:/...
# 2  ['https://web.archive.org/web/20201019/https:/...
# 3  ['https://web.archive.org/web/20201019/https:/...
# ...

# %% [markdown]
# This record of historic Editions partners could be a useful reference to compare present day Editions with however the data is likely too sparse to derive meaningful insights on how Editions has grown throughout the years. To build a map of Deliveroo Editions, we look for current data that we can scrape from Deliveroo.

# %% [markdown]
# ## Present Data

# %% [markdown]
# Many of the Editions locations can be found by searching the Food Standards Agency for businesses with "Deliveroo" in the title. Every kitchen in the UK requires an FSA rating and Deliveroo's Editions are recognised as maintaining solid hygiene ratings across their facilities. This is a far cry from the supposed unsavoury origins of the term 'dark kitchen' in New York's unregulated residential kitchens advertising through Grubhub platform [New York's unregulated kitchens](https://www.nbcnewyork.com/news/local/seamless-restaurant-grubhub-fake-eatery-unregulated-kitchen-investigation-i-team-new-york-city/2013699/).

# %% [markdown]
# ![](assets/fsa.png)

# %% [markdown]
# We can cross reference these addresses with editions names encountered from searching Deliveroo's site:

# %% [markdown]
# - 'bsy-2-editions': [Deliveroo sp ltd](https://ratings.food.gov.uk/business/en-GB/1381479/Deliveroo-sp-ltd-Ormside-Street) @ 145 Ormside Street London
# SE15 1TF
# - 'honor-oak-park': [Deliveroo SP Ltd](https://ratings.food.gov.uk/business/en-GB/1600766/Deliveroo-SP-Ltd-Malham-Road) @ Units 3-4 Dulwich Business Centre Malham Road Forest Hill
# SE23 1AG
# - 'culvert-place-editions': [Deliveroo](https://ratings.food.gov.uk/business/en-GB/1573230/Deliveroo-Culvert-Place) @ Unit 2 Editions Battersea 15a Parkfield Industrial Estate Culvert Place London
# SW115BA
# To get all of the restaurants we can search Deliveroo with a postcode from all of the ~2900 postcode districts in the UK filtering for editions. Whilst this is highly inefficient given that Deliveroo is not operating at most UK postcodes outside of cities and large towns, it does give a comprehensive picture.

# %% [markdown]
# ## Mapping Deliveroo Editions

# %% [markdown]
# **238 editions partners** were identified across **53 addresses** and **12 regions** in the UK as shown in the map below:

# %%
from IPython.display import IFrame
IFrame(src="data/editions_extra.html", width='100%', height='900px')
# Out:
#         <iframe
#             width="100%"
#             height="900px"
#             src="data/editions_extra.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
#|echo: false
df = pd.read_csv('data/editions_uk_18_7_23_.csv', usecols=['name','location','edition', 'restaurant_url', 'address', 'lat', 'lon'])
df.head()
# Out:
#               name location         edition  \
# 0  Yacob's Kitchen   London  bsy-1-editions
# 1      Shake Shack   London  bsy-1-editions
# 2       Poke Shack   London  bsy-1-editions
# 3         Dishoom    London  bsy-2-editions
# 4        WING·STOP   London  bsy-2-editions
#
#                                       restaurant_url  \
# 0  https://deliveroo.co.uk/menu/London/bsy-1-edit...
# 1  https://deliveroo.co.uk/menu/London/bsy-1-edit...
# 2  https://deliveroo.co.uk/menu/London/bsy-1-edit...
# 3  https://deliveroo.co.uk/menu/London/bsy-2-edit...
# 4  https://deliveroo.co.uk/menu/London/bsy-2-edit...
#
#                                              address        lat       lon
# 0  Unit 9, British Wharf, Landmann Way, London, S...  51.484623 -0.044459
# 1  Unit 9, British Wharf, Landmann Way, London, S...  51.484623 -0.044459
# 2  Unit 9, British Wharf, Landmann Way, London, S...  51.484623 -0.044459
# 3  145 Ormside Street, South Bermondsey, London, ...  51.483107 -0.055627
# ...

# %% [markdown]
# Wingstop ([2021 Deliveroo Restaurant of the Year winner](https://deliveroorestaurantawards.com/)), Dishoom ([2021 Deliveroo Best Indian Restaurant winner](https://deliveroorestaurantawards.com/)) and the Athenian appear to be the most scalable kitchens appearing in 6+ Editions across the UK. Its also common to find the Californian CBD drinks vendors 'Trip CBD Store' and Ben & Jerry's at editions sites.

# %%
#|echo: false
vendors = df[['name', 'edition']].drop_duplicates().reset_index(drop=True)
vendors['name'].value_counts().head(10).plot.barh()
plt.xlabel('editions')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       2 vendors = df[['name', 'edition']].drop_duplicates().reset_index(drop=True)
#       3 vendors['name'].value_counts().head(10).plot.barh()
# ----> 4 plt.xlabel('editions')
#       5 plt.show()
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ![](assets/wings.jpeg)

# %% [markdown]
# Of the 12 regions Editions has scaled to, London has 32 editions locations compared to the 21 locations spread across all other regions of the UK:

# %%
kitchen_subset = df[['location', 'edition']].drop_duplicates().reset_index(drop=True)
kitchen_subset['location'].value_counts().head(12).plot.barh()
# Out:
# <Axes: ylabel='location'>

# %% [markdown]
# London also offers the greatest choice of vendors at 127 compared to the 112 vendors spread across the other Editions sites.

# %%
df['location'].value_counts().head(10).plot.barh()
# Out:
# <Axes: ylabel='location'>

# %% [markdown]
# The busiest single Editions site is at Leeds with 22 vendors under one roof:

# %%
df['edition'].value_counts().head(10).plot.barh()
# Out:
# <Axes: ylabel='edition'>

# %% [markdown]
# ![](assets/leeds.png)
